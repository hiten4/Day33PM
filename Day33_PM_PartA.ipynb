# %% [markdown]
# <a href="https://colab.research.google.com/github/hiten4/Day33PM/blob/main/Day33_PM_PartA.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # Day 33 (PM) — Part A

# %% [markdown]
# ## 1. Import Libraries

# %%
import pandas as pd
import numpy as np

from sklearn.datasets import load_breast_cancer
from sklearn.model_selection import cross_val_score
from sklearn.preprocessing import StandardScaler

from sklearn.linear_model import LogisticRegression
from sklearn.tree import DecisionTreeClassifier
from sklearn.ensemble import RandomForestClassifier
from sklearn.svm import SVC
from sklearn.neighbors import KNeighborsClassifier
from sklearn.naive_bayes import GaussianNB
from sklearn.ensemble import GradientBoostingClassifier
from sklearn.ensemble import AdaBoostClassifier

# %% [markdown]
# ## 2. Load Dataset

# %%
data = load_breast_cancer()
X = data.data
y = data.target

scaler = StandardScaler()
X = scaler.fit_transform(X)

# %% [markdown]
# ## 3. Algorithm Cards

# %% [markdown]
# ### Logistic Regression
# When: Linear relationships, baseline model
# Params: C, penalty
# Pros: Simple, interpretable
# Cons: Cannot capture complex patterns
# Code: LogisticRegression().fit(X,y)

# %% [markdown]
# ### Decision Tree
# When: Interpretability needed
# Params: max_depth, min_samples_split
# Pros: Easy to explain
# Cons: Overfitting
# Code: DecisionTreeClassifier().fit(X,y)

# %% [markdown]
# ### Random Forest
# When: High accuracy required
# Params: n_estimators, max_depth
# Pros: Reduces overfitting
# Cons: Less interpretable
# Code: RandomForestClassifier().fit(X,y)

# %% [markdown]
# ### SVM
# When: High-dimensional data
# Params: C, gamma, kernel
# Pros: Works well in complex spaces
# Cons: Slow for large datasets
# Code: SVC(kernel='rbf').fit(X,y)

# %% [markdown]
# ### KNN
# When: Small datasets
# Params: n_neighbors
# Pros: Simple
# Cons: Slow prediction
# Code: KNeighborsClassifier().fit(X,y)

# %% [markdown]
# ### Naive Bayes
# When: Text data
# Params: None major
# Pros: Fast
# Cons: Strong assumptions
# Code: GaussianNB().fit(X,y)

# %% [markdown]
# ### Gradient Boosting
# When: High performance needed
# Params: n_estimators, learning_rate
# Pros: Powerful
# Cons: Slow
# Code: GradientBoostingClassifier().fit(X,y)

# %% [markdown]
# ### AdaBoost
# When: Weak learners boosting
# Params: n_estimators
# Pros: Improves weak models
# Cons: Sensitive to noise
# Code: AdaBoostClassifier().fit(X,y)

# %% [markdown]
# ## 4. Model Comparison (Cross Validation)

# %%
models = {
    "Logistic": LogisticRegression(max_iter=1000),
    "DecisionTree": DecisionTreeClassifier(),
    "RandomForest": RandomForestClassifier(),
    "SVM": SVC(),
    "KNN": KNeighborsClassifier(),
    "NaiveBayes": GaussianNB(),
    "GradientBoosting": GradientBoostingClassifier(),
    "AdaBoost": AdaBoostClassifier()
}

results = {}

for name, model in models.items():
    scores = cross_val_score(model, X, y, cv=5, scoring='accuracy')
    results[name] = scores.mean()

results_df = pd.DataFrame(list(results.items()), columns=["Model", "Accuracy"])
results_df = results_df.sort_values(by="Accuracy", ascending=False)

print(results_df)
# Out:
#               Model  Accuracy
# 0          Logistic  0.980686
# 3               SVM  0.973638
# 7          AdaBoost  0.966620
# 2      RandomForest  0.964866
# 4               KNN  0.964850
# 6  GradientBoosting  0.961372
# 5        NaiveBayes  0.927930
# 1      DecisionTree  0.922636

# %% [markdown]
# ## 5. Recommendation
#
# Tree-based ensemble models like Random Forest and Gradient Boosting generally perform best on tabular data due to their ability to capture non-linear relationships. Logistic Regression serves as a strong baseline, while SVM performs well in high-dimensional spaces.
#
# Based on cross-validation accuracy, the best model can be selected depending on the dataset characteristics.
